# %%
pip install tweepy

# %%
#IMPORTAR neomdel
from neomodel import StructuredNode, StringProperty, RelationshipTo, RelationshipFrom, config, IntegerProperty, UniqueIdProperty, UniqueIdProperty

#URL CONECCION CON LA BASE DE DATOS DE NEO4J
config.DATABASE_URL = 'bolt://neo4j:Proyecto@localhost:11003'

#CREAR Object PAIS
class PAIS(StructuredNode):
    nombre = StringProperty(unique_index=True)
    datos = RelationshipFrom('UBICACION','CIUDAD')

#CREAR Object USUARIOS
class USUARIOS(StructuredNode):
    nombre = StringProperty(unique_index=True)
    datos = RelationshipTo('DATOS','DATOS')
    ubicacion = RelationshipTo('UBICACION','UBICACION')
    
#CREAR Object UBICACION 
class UBICACION(StructuredNode):
    location = StringProperty(unique_index=True)
    usuarios = RelationshipFrom('USUARIOS','UBICACION')
    pais = RelationshipTo('PAIS','CIUDAD') 

#CREAR Object DATOS 
class DATOS(StructuredNode):
    fecha = StringProperty(unique_index=True)
    url = StringProperty(unique_index=True)
    texto = StringProperty(unique_index=True)
    publicado_desde = StringProperty(unique_index=True)
    favorite_count = StringProperty(unique_index=True)
    retweet_count = StringProperty(unique_index=True)
    usuarios = RelationshipFrom('USUARIOS','DATOS')

# %%
ecuador = PAIS(nombre='Ecuador').save()
sinpais = PAIS(nombre='SIN PAIS DEFINIDO').save()
sinlocation = UBICACION(location = 'Sin Localizacion').save()

# %%
import random
import tweepy
consumer_key = 'wOqfYXUaEAK4opOf12SzXsv5a'
consumer_secret = 'QdSwmEq0caIUUhjxHROI7cy9acc2VDKSNRNtHj8VFrwfeA6tNR'
access_token = '1098316174327197696-EEZRo8Bx0I1vsQFviAxS5dasbbZXHp'
access_token_secret = 'Iu4n9CfASIlv1EurM1BYBmRmDdLDlrPeJ6AukXa7D0C1F'

# %%
import tweepy
import json
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
cont = 1
conts = 0
language = 'es'
ubicacion = []
user = []
location = ""
name = ""
pais = ""
paisEc = 'Ecuador'
try :
    
    for tweet in tweepy.Cursor(api.search, q="Guillermo Lasso", tweet_mode="extended",lang=language).items(1000000000):  
        if (not tweet.retweeted) and ('RT @' not in tweet.full_text):
        
            if cont <= 5000:

                print("")
                print(cont,'.', tweet.created_at,"-- Texto --",tweet.full_text,"-- Coordenadas --",tweet.coordinates,
                      "-- Publicado desde --",tweet.source, "-- Me gusta--",tweet.favorite_count, " -- Retweet --", tweet.retweet_count,
                      " -- Datos del Usuario -- Nombre del Usuario-- ",tweet.user.name, "--- Localizacion ---", tweet.user.location,
                      "--- URL ---- ",tweet.user.url )
                location = str(tweet.user.location)
                location = location.lstrip()
                name = str(tweet.user.name)

                if(name in user):
                    

                    print("Si Existe Persona")
                    if(location.strip()):
                        locatt = ""
                        locatt = str(location)
                        print(locatt)
                        if(', ' in locatt):
                            print("ES SEPARADO POR COMA")
                            pais = location.split(", ")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    nam.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    nam.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    location = UBICACION(location = location).save()
                                    location.pais.connect(ecuador)

                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    nam.datos.connect(datos)
                                    nam.ubicacion.connect(location)

                        elif ('-' in locatt):
                            print("ES SEPARADO POR GUION")
                            pais = location.split("-")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    nam.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    nam.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    location = UBICACION(location = location).save()
                                    location.pais.connect(ecuador)
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    nam.datos.connect(datos)
                                    nam.ubicacion.connect(location)

                            else:
                                print("NO ES DEL PAIS ECUADOR")

                        else:
                            print('NO TIENE COMA')
                            if location in ubicacion:
                                print("Si Existe Localización")
                                name = USUARIOS(nombre = name).save()
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                name.datos.connect(datos)
                                location = UBICACION.nodes.first(location=location)
                                location.pais.connect(sinpais)
                                name.ubicacion.connect(location)

                            else:
                                print("No existe Localización")
                                if location[0] in " ":
                                    print(location)
                                    print("Tiene un espacio blanco")
                                    location = location.replace(' ','')
                                    print(location)
                                else :
                                    print("No Tiene un espacio blanco")
                                    
                                ubicacion.append(location)
                                nam = USUARIOS.nodes.first(nombre=name)
                                location = UBICACION(location = location).save()
                                location.pais.connect(sinpais)
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                nam.datos.connect(datos)
                                nam.ubicacion.connect(location)

                    else:
                        nam = USUARIOS.nodes.first(nombre=name)
                        datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                        nam.datos.connect(datos)
                        nam.ubicacion.connect(sinlocation)


                else:

                    user.append(name)
                    print("No Existe Persona")

                    if(location.strip()):
                        locatt = ""
                        locatt = str(location)
                        print(locatt)
                        if(', ' in locatt):
                            print("ES SEPARADO POR COMA A")
                            pais = location.split(", ")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    name.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    name.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    location = UBICACION(location = str(location)).save()
                                    location.pais.connect(ecuador)
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    name.datos.connect(datos)
                                    name.ubicacion.connect(location)

                            else:
                                print("NO ES DEL PAIS ECUADOR")

                        elif ('-' in locatt):
                            print("ES SEPARADO POR COMA -")
                            pais = location.split("-")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    name.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    name.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    location = UBICACION(location = str(location)).save()
                                    location.pais.connect(ecuador)
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    name.datos.connect(datos)
                                    name.ubicacion.connect(location)

                            else:
                                print("NO ES DEL PAIS ECUADOR")
                        else:
                            print('NO TIENE COMA')
                            if location in ubicacion:
                                print("Si Existe Localización")
                                name = USUARIOS(nombre = name).save()
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                name.datos.connect(datos)
                                location = UBICACION.nodes.first(location=location)
                                location.pais.connect(sinpais)
                                name.ubicacion.connect(location)


                            else:
                                print("No existe Localización")
                                if location[0] in " ":
                                    print(location)
                                    print("Tiene un espacio blanco")
                                    location = location.replace(' ','')
                                    print(location)
                                else :
                                    print("No Tiene un espacio blanco")
                                print(location)
                                ubicacion.append(location)
                                location = UBICACION(location = location).save()
                                location.pais.connect(sinpais)
                                name = USUARIOS(nombre = name).save()
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                name.datos.connect(datos)
                                name.ubicacion.connect(location)



                    else:
                        name = USUARIOS(nombre = name).save()
                        datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                        name.datos.connect(datos)
                        name.ubicacion.connect(sinlocation)


                cont = cont+1
            else:
                print('Llego a las 5000 Datos')
                break;


        conts = conts+1
    
except TimeoutError:
    print('TimeoutError')
except NewConnectionError:
    print('NewConnectionError')
except MaxRetryError:
    print('MaxRetryError')
except NewConnectionError:
    print('ConnectionError')
except TweepError:
    print('TweepError')  
except UBICACIONDoesNotExist:
    print('UBICACIONDoesNotExist')
except NameError:
    print('NameError')
# Out:
# 1 . 2021-01-05 17:24:10 -- Texto -- 3. Villamayor se desempeña también como abogado defen­sor de los ciudadanos españo­les Álvaro Lasso y Guillermo Casado, representantes de la firma Proibérica, acusados en el caso de la compra irregular de cuatro helicópteros para la Policía Nacional
# 3/4 -- Coordenadas -- None -- Publicado desde -- Twitter for Android -- Me gusta-- 0  -- Retweet -- 0  -- Datos del Usuario -- Nombre del Usuario--  Beto --- Localizacion ---  --- URL ----  None
# No Existe Persona
#
# ...

# %%
from py2neo import Node, Relationship, Graph


# connect to authenticated graph database
graph = Graph("bolt://localhost:11003", aut="neo4j", password="Proyecto", secure=False)

ciudad = str(graph.run('MATCH relation=(u:UBICACION)-[r:CIUDAD]->(n:PAIS) WHERE n.nombre="Ecuador" return  u.location').data())
ciudad = ciudad.replace("[",'')
ciudad = ciudad.replace("]",'')
ciudad = ciudad.replace("{",'')
ciudad = ciudad.replace("}",'')
ciudad = ciudad.replace("'u.location':",'')
ciudad = ciudad.replace("  '",'')
ciudad = ciudad.replace(" '",'')
ciudad = ciudad.replace("'",'')
ciudad = string.split(',')
contc = 0 
contu = 0
for contc in range(len(ciudad)):
    usuario = str(graph.run('MATCH relation=(u:USUARIOS)-[r:UBICACION]->(n:UBICACION) WHERE n.location="'+ciudad[contc]+'" return  u.nombre').data())
    usuario = usuario.replace("[",'')
    usuario = usuario.replace("]",'')
    usuario = usuario.replace("{",'')
    usuario = usuario.replace("}",'')
    usuario = usuario.replace("'u.nombre':",'')
    usuario = usuario.replace("  '",'')
    usuario = usuario.replace(" '",'')
    usuario = usuario.replace("'",'')
    usuario = usuario.split(',')
    
    if((len(usuario)) < 2):
        print("Solo es uno")
    else:
        print("Es más de uno")
        for contu in range(len(usuario)):
            try:
                #print('MATCH (n:USUARIOS) WHERE n.nombre="'+usuario[contu]+'" return  n'
                graph.run("MATCH (o:USUARIOS {nombre:'"+usuario[contu]+"'}), (c:USUARIOS {nombre:'"+usuario[contu+1]+"'})CREATE (o)-[:CONOCE]->(c)").data()
                graph.run("MATCH (o:USUARIOS {nombre:'"+usuario[contu]+"'}), (c:USUARIOS {nombre:'"+usuario[contu+2]+"'})CREATE (o)-[:CONOCE]->(c)").data()
                contu = contu + 1
            except IndexError:
                print('error')
            if (contu >(len(usuario)-2)):
                break;
                
    
    contc = contc + 1
# Out:
# Es más de uno
# error
# error
# Es más de uno
# error
# error
# Es más de uno
# error
# error
# Es más de uno
# error
# error
# Es más de uno
# error
# error

# %%
import tweepy
import json
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
cont = 1
conts = 0
language = 'es'
ubicacion = []
user = []
location = ""
name = ""
pais = ""
paisEc = 'Ecuador'
try :
    
    for tweet in tweepy.Cursor(api.search, q="@LassoGuillermo", tweet_mode="extended",lang=language).items(1000000000):  
        if (not tweet.retweeted) and ('RT @' not in tweet.full_text):
        
            if cont <= 5000:

                print("")
                print(cont,'.', tweet.created_at,"-- Texto --",tweet.full_text,"-- Coordenadas --",tweet.coordinates,
                      "-- Publicado desde --",tweet.source, "-- Me gusta--",tweet.favorite_count, " -- Retweet --", tweet.retweet_count,
                      " -- Datos del Usuario -- Nombre del Usuario-- ",tweet.user.name, "--- Localizacion ---", tweet.user.location,
                      "--- URL ---- ",tweet.user.url )
                location = str(tweet.user.location)
                location = location.lstrip()
                name = str(tweet.user.name)

                if(name in user):
                    

                    print("Si Existe Persona")
                    if(location.strip()):
                        locatt = ""
                        locatt = str(location)
                        print(locatt)
                        if(', ' in locatt):
                            print("ES SEPARADO POR COMA")
                            pais = location.split(", ")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    nam.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    nam.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    location = UBICACION(location = location).save()
                                    location.pais.connect(ecuador)

                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    nam.datos.connect(datos)
                                    nam.ubicacion.connect(location)

                        elif ('-' in locatt):
                            print("ES SEPARADO POR GUION")
                            pais = location.split("-")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    nam.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    nam.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    nam = USUARIOS.nodes.first(nombre=name)
                                    location = UBICACION(location = location).save()
                                    location.pais.connect(ecuador)
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    nam.datos.connect(datos)
                                    nam.ubicacion.connect(location)

                            else:
                                print("NO ES DEL PAIS ECUADOR")

                        else:
                            print('NO TIENE COMA')
                            if location in ubicacion:
                                print("Si Existe Localización")
                                name = USUARIOS(nombre = name).save()
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                name.datos.connect(datos)
                                location = UBICACION.nodes.first(location=location)
                                location.pais.connect(sinpais)
                                name.ubicacion.connect(location)

                            else:
                                print("No existe Localización")
                                if location[0] in " ":
                                    print(location)
                                    print("Tiene un espacio blanco")
                                    location = location.replace(' ','')
                                    print(location)
                                else :
                                    print("No Tiene un espacio blanco")
                                    
                                ubicacion.append(location)
                                nam = USUARIOS.nodes.first(nombre=name)
                                location = UBICACION(location = location).save()
                                location.pais.connect(sinpais)
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                nam.datos.connect(datos)
                                nam.ubicacion.connect(location)

                    else:
                        nam = USUARIOS.nodes.first(nombre=name)
                        datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                        nam.datos.connect(datos)
                        nam.ubicacion.connect(sinlocation)


                else:

                    user.append(name)
                    print("No Existe Persona")

                    if(location.strip()):
                        locatt = ""
                        locatt = str(location)
                        print(locatt)
                        if(', ' in locatt):
                            print("ES SEPARADO POR COMA A")
                            pais = location.split(", ")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    name.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    name.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    location = UBICACION(location = str(location)).save()
                                    location.pais.connect(ecuador)
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    name.datos.connect(datos)
                                    name.ubicacion.connect(location)

                            else:
                                print("NO ES DEL PAIS ECUADOR")

                        elif ('-' in locatt):
                            print("ES SEPARADO POR COMA -")
                            pais = location.split("-")
                            location = str(pais[0])
                            location = location.replace(' ','')
                            pais = str(pais[1])
                            pais = pais.replace(' ','')
                            if(pais.upper() ==  paisEc.upper()):
                                print("PAIS ECUADOR")
                                if location in ubicacion:
                                    print("Si Existe Localización")
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                    name.datos.connect(datos)
                                    location = UBICACION.nodes.first(location=location)
                                    location.pais.connect(ecuador)
                                    name.ubicacion.connect(location)

                                else:
                                    print("No existe Localización")
                                    if location[0] in " ":
                                        print(location)
                                        print("Tiene un espacio blanco")
                                        location = location.replace(' ','')
                                        print(location)
                                    else :
                                        print("No Tiene un espacio blanco")
                                    ubicacion.append(location)
                                    location = UBICACION(location = str(location)).save()
                                    location.pais.connect(ecuador)
                                    name = USUARIOS(nombre = name).save()
                                    datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                    name.datos.connect(datos)
                                    name.ubicacion.connect(location)

                            else:
                                print("NO ES DEL PAIS ECUADOR")
                        else:
                            print('NO TIENE COMA')
                            if location in ubicacion:
                                print("Si Existe Localización")
                                name = USUARIOS(nombre = name).save()
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()             
                                name.datos.connect(datos)
                                location = UBICACION.nodes.first(location=location)
                                location.pais.connect(sinpais)
                                name.ubicacion.connect(location)


                            else:
                                print("No existe Localización")
                                if location[0] in " ":
                                    print(location)
                                    print("Tiene un espacio blanco")
                                    location = location.replace(' ','')
                                    print(location)
                                else :
                                    print("No Tiene un espacio blanco")
                                print(location)
                                ubicacion.append(location)
                                location = UBICACION(location = location).save()
                                location.pais.connect(sinpais)
                                name = USUARIOS(nombre = name).save()
                                datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                                name.datos.connect(datos)
                                name.ubicacion.connect(location)



                    else:
                        name = USUARIOS(nombre = name).save()
                        datos = DATOS(fecha = str(tweet.created_at),url = str(tweet.user.url),texto = str(tweet.full_text),publicado_desde = str(tweet.source), favorite_count = str(tweet.favorite_count),retweet_count = str(tweet.retweet_count)).save()
                        name.datos.connect(datos)
                        name.ubicacion.connect(sinlocation)


                cont = cont+1
            else:
                print('Llego a las 5000 Datos')
                break;


        conts = conts+1
    
except TimeoutError:
    print('TimeoutError')
except NewConnectionError:
    print('NewConnectionError')
except MaxRetryError:
    print('MaxRetryError')
except NewConnectionError:
    print('ConnectionError')
except TweepError:
    print('TweepError')  
except UBICACIONDoesNotExist:
    print('UBICACIONDoesNotExist')
except NameError:
    print('NameError')
# Out:
# 1 . 2021-01-05 19:06:51 -- Texto -- @FelixPilcoGye @LassoGuillermo Entonces deberías hacer encuestas, porque el porcentaje de @LassoGuillermo en Manabí no llega al 10% y en  Guayas apenas llega al 15%. Con esos montos es imposible ganar la Presidencia. Recuerda que Pedernales es puro empresario camaronero. Ven a Manta, Portoviejo y Chone -- Coordenadas -- None -- Publicado desde -- Twitter for Android -- Me gusta-- 0  -- Retweet -- 0  -- Datos del Usuario -- Nombre del Usuario--  Omar Maluk Salem🐐 --- Localizacion --- Ecuador --- URL ----  None
# No Existe Persona
# Ecuador
# NO TIENE COMA
# No existe Localización
# No Tiene un espacio blanco
# Ecuador
#
# ...
